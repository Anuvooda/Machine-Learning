# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_excel('C:\Users\ANU\Desktop\D3_Main_Project\updated_blood_glucose_dataset.xlsx')

# Display the first few rows
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 8
#       5 import seaborn as sns
#       7 # Load the dataset
# ----> 8 df = pd.read_excel('/content/updated_blood_glucose_dataset.xlsx')
#      10 # Display the first few rows
#      11 df.head()
#
# File c:\Users\kar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
# ...

# %%
# Shape of the dataset
print(f"Rows: {df.shape[0]}, Columns: {df.shape[1]}")

# Data types and null values
df.info()
# Out:
# Rows: 1000, Columns: 11
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Blood Glucose Levels (mg/dl)  1000 non-null   int64
#  1   Physically Active Status      1000 non-null   object
#  2   BMI (kg/m²)                   1000 non-null   float64
#  3   Insulin Values (µU/mL)        1000 non-null   float64
#  4   Age (years)                   1000 non-null   int64
#  5   Dietary Habits                1000 non-null   object
#  6   Family History of Diabetes    1000 non-null   object
#  7   Blood Pressure (mmHg)         1000 non-null   object
#  8   HbA1c (%)                     1000 non-null   float64
#  9   Cholesterol Levels (mg/dl)    1000 non-null   int64
#  10  Insulin Dosage(units)         1000 non-null   int64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 86.1+ KB

# %%
# Summary statistics
df.describe()
# Out:
#        Blood Glucose Levels (mg/dl)  BMI (kg/m²)  Insulin Values (µU/mL)  \
# count                   1000.000000   1000.00000             1000.000000
# mean                     243.746000     25.92390               35.322300
# std                       63.161863      4.57411               14.591726
# min                      131.000000     18.00000               10.000000
# 25%                      188.000000     21.80000               22.475000
# 50%                      246.000000     26.05000               36.300000
# 75%                      296.000000     29.90000               48.000000
# max                      350.000000     33.90000               60.000000
#
#        Age (years)    HbA1c (%)  Cholesterol Levels (mg/dl)  \
# count  1000.000000  1000.000000                 1000.000000
# mean     50.279000     7.259900                  224.627000
# std      18.261781     1.569141                   43.470191
# min      18.000000     4.500000                  150.000000
# ...

# %%
# Count of missing values
missing_values = df.isnull().sum()
print(missing_values)

# Visualize missing values
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()
# Out:
# Blood Glucose Levels (mg/dl)    0
# Physically Active Status        0
# BMI (kg/m²)                     0
# Insulin Values (µU/mL)          0
# Age (years)                     0
# Dietary Habits                  0
# Family History of Diabetes      0
# Blood Pressure (mmHg)           0
# HbA1c (%)                       0
# Cholesterol Levels (mg/dl)      0
# Insulin Dosage(units)           0
# dtype: int64

# %%
# Check unique values in each column
for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values")
# Out:
# Blood Glucose Levels (mg/dl): 218 unique values
# Physically Active Status: 2 unique values
# BMI (kg/m²): 160 unique values
# Insulin Values (µU/mL): 429 unique values
# Age (years): 63 unique values
# Dietary Habits: 3 unique values
# Family History of Diabetes: 2 unique values
# Blood Pressure (mmHg): 521 unique values
# HbA1c (%): 56 unique values
# Cholesterol Levels (mg/dl): 151 unique values
# Insulin Dosage(units): 6 unique values

# %%
# Compute and visualize correlation matrix
# Include numeric_only=True to only calculate correlations for numerical columns
correlation_matrix = df.corr(numeric_only=True)

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
# Histograms for numerical features
df.hist(figsize=(15, 10), bins=20, color='skyblue')
plt.suptitle('Distribution of Numerical Features', size=16)
plt.show()

# %%
# Boxplots for numeric features
plt.figure(figsize=(15, 10))
sns.boxplot(data=df, palette="Set3")
plt.title('Boxplot of Numerical Features')
plt.xticks(rotation=45)
plt.show()

# %%
# Check for duplicate rows
duplicate_rows = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_rows}")

# Drop duplicates
df = df.drop_duplicates()
print(f"Shape after removing duplicates: {df.shape}")
# Out:
# Number of duplicate rows: 0
# Shape after removing duplicates: (1000, 11)
